# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("vaccinations.csv")

# %%
data.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146273 entries, 0 to 146272
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             146273 non-null  object
#  1   iso_code                             146273 non-null  object
#  2   date                                 146273 non-null  object
#  3   total_vaccinations                   69499 non-null   float64
#  4   people_vaccinated                    66452 non-null   float64
#  5   people_fully_vaccinated              63821 non-null   float64
#  6   total_boosters                       38577 non-null   float64
#  7   daily_vaccinations_raw               57638 non-null   float64
#  8   daily_vaccinations                   145381 non-null  float64
#  9   total_vaccinations_per_hundred       69499 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# location                                    0
# iso_code                                    0
# date                                        0
# total_vaccinations                      76774
# people_vaccinated                       79821
# people_fully_vaccinated                 82452
# total_boosters                         107696
# daily_vaccinations_raw                  88635
# daily_vaccinations                        892
# total_vaccinations_per_hundred          76774
# people_vaccinated_per_hundred           79821
# people_fully_vaccinated_per_hundred     82452
# total_boosters_per_hundred             107696
# daily_vaccinations_per_million            892
# daily_people_vaccinated                  1157
# daily_people_vaccinated_per_hundred      1157
# dtype: int64

# %%
data_odb = data[['location','date','people_vaccinated']]
data_odb = data_odb.loc[(data_odb['location']=='Brazil')]
data_tdb = data[['location','date','people_fully_vaccinated']]
data_tdb = data_tdb.loc[(data_tdb['location']=='Brazil')]
data_bb = data[['location','date','total_boosters']]
data_bb = data_bb.loc[(data_bb['location']=='Brazil')]
data_odusa = data[['location','date','people_vaccinated']]
data_odusa = data_odusa.loc[(data_odusa['location']=='United States')]
data_tdusa = data[['location','date','people_fully_vaccinated']]
data_tdusa = data_tdusa.loc[(data_tdusa['location']=='United States')]
data_busa = data[['location','date','total_boosters']]
data_busa = data_busa.loc[(data_busa['location']=='United States')]
data_odchn = data[['location','date','people_vaccinated']]
data_odchn = data_odchn.loc[(data_odchn['location']=='China')]
data_tdchn = data[['location','date','people_fully_vaccinated']]
data_tdchn = data_tdchn.loc[(data_tdchn['location']=='China')]
data_bchn = data[['location','date','total_boosters']]
data_bchn = data_bchn.loc[(data_bchn['location']=='China')]
data_odrus = data[['location','date','people_vaccinated']]
data_odrus = data_odrus.loc[(data_odrus['location']=='Russia')]
data_tdrus = data[['location','date','people_fully_vaccinated']]
data_tdrus = data_tdrus.loc[(data_tdrus['location']=='Russia')]
data_brus = data[['location','date','total_boosters']]
data_brus = data_brus.loc[(data_brus['location']=='Russia')]

# %%
data_tdb.head()
# Out:
#       location        date  people_fully_vaccinated
# 17859   Brazil  2021-01-17                      NaN
# 17860   Brazil  2021-01-18                      NaN
# 17861   Brazil  2021-01-19                      NaN
# 17862   Brazil  2021-01-20                      NaN
# 17863   Brazil  2021-01-21                      NaN

# %%
data_tdusa.head()
# Out:
#              location        date  people_fully_vaccinated
# 137920  United States  2020-12-13                   8867.0
# 137921  United States  2020-12-14                   9021.0
# 137922  United States  2020-12-15                   9337.0
# 137923  United States  2020-12-16                   9842.0
# 137924  United States  2020-12-17                  10650.0

# %%
data_busa.isnull().sum()
# Out:
# location            0
# date                0
# total_boosters    163
# dtype: int64

# %%
data_tdchn.head()
# Out:
#       location        date  people_fully_vaccinated
# 26409    China  2020-12-15                      NaN
# 26410    China  2020-12-16                      NaN
# 26411    China  2020-12-17                      NaN
# 26412    China  2020-12-18                      NaN
# 26413    China  2020-12-19                      NaN

# %%
data_tdrus.head()
# Out:
#        location        date  people_fully_vaccinated
# 108149   Russia  2020-12-15                      NaN
# 108150   Russia  2020-12-16                      NaN
# 108151   Russia  2020-12-17                      NaN
# 108152   Russia  2020-12-18                      NaN
# 108153   Russia  2020-12-19                      NaN

# %%
data_brus.head()
# Out:
#        location        date  total_boosters
# 108149   Russia  2020-12-15             NaN
# 108150   Russia  2020-12-16             NaN
# 108151   Russia  2020-12-17             NaN
# 108152   Russia  2020-12-18             NaN
# 108153   Russia  2020-12-19             NaN

# %%
data_odb = data_odb.dropna()
data_tdb = data_tdb.dropna()
data_bb = data_bb.dropna()
data_odusa = data_odusa.dropna()
data_tdusa = data_tdusa.dropna()
data_busa = data_busa.dropna()
data_odrus = data_odrus.dropna()
data_tdrus = data_tdrus.dropna()
data_brus = data_brus.dropna() 
data_odchn = data_odchn.dropna()
data_tdchn = data_tdchn.dropna()
data_bchn = data_bchn.dropna()

# %%
data_tdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 17878 to 18566
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 611 non-null    object
#  1   date                     611 non-null    object
#  2   people_fully_vaccinated  611 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 19.1+ KB

# %%
data_tdusa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 738 entries, 137920 to 138657
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 738 non-null    object
#  1   date                     738 non-null    object
#  2   people_fully_vaccinated  738 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 23.1+ KB

# %%
data_bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 18087 to 18566
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        400 non-null    object
#  1   date            400 non-null    object
#  2   total_boosters  400 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 12.5+ KB

# %%
data_odb['date'] = pd.to_datetime(data_odb['date'])
data_tdb['date'] = pd.to_datetime(data_tdb['date'])
data_bb['date'] = pd.to_datetime(data_bb['date'])
data_odusa['date'] = pd.to_datetime(data_odusa['date'])
data_tdusa['date'] = pd.to_datetime(data_tdusa['date'])
data_busa['date'] = pd.to_datetime(data_busa['date'])
data_odrus['date'] = pd.to_datetime(data_odrus['date'])
data_tdrus['date'] = pd.to_datetime(data_tdrus['date'])
data_brus['date'] = pd.to_datetime(data_brus['date'])
data_odchn['date'] = pd.to_datetime(data_odchn['date'])
data_tdchn['date'] = pd.to_datetime(data_tdchn['date'])
data_bchn['date'] = pd.to_datetime(data_bchn['date'])

# %%
figure, axis = plt.subplots(nrows = 2, ncols = 2, figsize=(15, 15))

#Grafico Brasil
axis[0,0].plot(data_odb['date'], data_odb['people_vaccinated'],color='blue')
axis[0,0].plot(data_tdb['date'], data_tdb['people_fully_vaccinated'],color='red')
axis[0,0].plot(data_bb['date'], data_bb['total_boosters'],color='green')
axis[0,0].set_title("Brasil",fontsize=15)
axis[0,0].set_xlabel('Data', fontsize=15)

#Grafico USA
axis[0,1].plot(data_odusa['date'], data_odusa['people_vaccinated'],color='blue')
axis[0,1].plot(data_tdusa['date'], data_tdusa['people_fully_vaccinated'],color='red')
axis[0,1].plot(data_busa['date'], data_busa['total_boosters'],color='green')
axis[0,1].set_title("Estados Unidos",fontsize=15)
axis[0,1].set_xlabel('Data', fontsize=15)

#Grafico CHINA
axis[1,0].plot(data_odchn['date'], data_odchn['people_vaccinated'],color='blue')
axis[1,0].plot(data_tdchn['date'], data_tdchn['people_fully_vaccinated'],color='red')
axis[1,0].plot(data_bchn['date'], data_bchn['total_boosters'],color='green')
axis[1,0].set_title("China",fontsize=15)
axis[1,0].set_xlabel('Data', fontsize=15)

#Grafico RUSSIA
axis[1,1].plot(data_odrus['date'], data_odrus['people_vaccinated'],color='blue')
axis[1,1].plot(data_tdrus['date'], data_tdrus['people_fully_vaccinated'],color='red')
axis[1,1].plot(data_brus['date'], data_brus['total_boosters'],color='green')
axis[1,1].set_title("Russia",fontsize=15)
axis[1,1].set_xlabel('Data', fontsize=15)
# Out:
# Text(0.5, 0, 'Data')

# %%
data_dpvhb = data[['location','date','daily_people_vaccinated_per_hundred']]
data_dpvhb = data_dpvhb.loc[(data_dpvhb['location']=='Brazil')]
data_dpvhb['date'] = pd.to_datetime(data_dpvhb['date'])

# %%
data_dpvhusa = data[['location','date','daily_people_vaccinated_per_hundred']]
data_dpvhusa = data_dpvhusa.loc[(data_dpvhusa['location']=='United States')]
data_dpvhusa['date'] = pd.to_datetime(data_dpvhusa['date'])

# %%
data_dpvhchn = data[['location','date','daily_people_vaccinated_per_hundred']]
data_dpvhchn = data_dpvhchn.loc[(data_dpvhchn['location']=='United States')]
data_dpvhchn['date'] = pd.to_datetime(data_dpvhchn['date'])

# %%
data_dpvhrus = data[['location','date','daily_people_vaccinated_per_hundred']]
data_dpvhrus = data_dpvhrus.loc[(data_dpvhrus['location']=='United States')]
data_dpvhrus['date'] = pd.to_datetime(data_dpvhrus['date'])

# %%
figure, axis = plt.subplots(nrows = 2, ncols = 2, figsize=(15, 15))

#Grafico Brasil
axis[0,0].plot(data_dpvhb['date'], data_dpvhb['daily_people_vaccinated_per_hundred'],color='blue')
axis[0,0].set_title("Brasil",fontsize=15)
axis[0,0].set_xlabel('Data', fontsize=15)

#Grafico USA
axis[0,1].plot(data_dpvhusa['date'], data_dpvhusa['daily_people_vaccinated_per_hundred'],color='red')
axis[0,1].set_title("Estados Unidos",fontsize=15)
axis[0,1].set_xlabel('Data', fontsize=15)

#Grafico CHINA
axis[1,0].plot(data_dpvhchn['date'], data_dpvhchn['daily_people_vaccinated_per_hundred'],color='green')
axis[1,0].set_title("China",fontsize=15)
axis[1,0].set_xlabel('Data', fontsize=15)

#Grafico RUSSIA
axis[1,1].plot(data_dpvhrus['date'], data_dpvhrus['daily_people_vaccinated_per_hundred'],color='black')
axis[1,1].set_title("Russia",fontsize=15)
axis[1,1].set_xlabel('Data', fontsize=15)
# Out:
# Text(0.5, 0, 'Data')

# %%
data = pd.read_csv("owid-covid-data.csv")

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245307 entries, 0 to 245306
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    245307 non-null  object
#  1   continent                                   231516 non-null  object
#  2   location                                    245307 non-null  object
#  3   date                                        245307 non-null  object
#  4   total_cases                                 231243 non-null  float64
#  5   new_cases                                   230858 non-null  float64
#  6   new_cases_smoothed                          229659 non-null  float64
#  7   total_deaths                                211794 non-null  float64
#  8   new_deaths                                  211673 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   13791
# location                                        0
# date                                            0
# total_cases                                 14064
#                                             ...
# population                                   1053
# excess_mortality_cumulative_absolute       237092
# excess_mortality_cumulative                237092
# excess_mortality                           237053
# excess_mortality_cumulative_per_million    237092
# Length: 67, dtype: int64

# %%
data_ncb = data[['location','date','new_cases']]
data_ncb = data_ncb.loc[(data_ncb['location']=='Brazil')]
data_ncb['date'] = pd.to_datetime(data_ncb['date'])
data_ncusa = data[['location','date','new_cases']]
data_ncusa = data_ncusa.loc[(data_ncusa['location']=='United States')]
data_ncusa['date'] = pd.to_datetime(data_ncusa['date'])
data_ncchn = data[['location','date','new_cases']]
data_ncchn = data_ncchn.loc[(data_ncchn['location']=='China')]
data_ncchn['date'] = pd.to_datetime(data_ncchn['date'])
data_ncrus = data[['location','date','new_cases']]
data_ncrus = data_ncrus.loc[(data_ncrus['location']=='Russia')]
data_ncrus['date'] = pd.to_datetime(data_ncrus['date'])

# %%
data_ncb.dropna()
data_ncusa.dropna()
data_ncchn.dropna()
data_ncrus.dropna()
# Out:
#        location       date  new_cases
# 181018   Russia 2020-01-31        2.0
# 181019   Russia 2020-02-01        0.0
# 181020   Russia 2020-02-02        0.0
# 181021   Russia 2020-02-03        0.0
# 181022   Russia 2020-02-04        0.0
# ...         ...        ...        ...
# 182073   Russia 2022-12-21     7403.0
# 182074   Russia 2022-12-22     7409.0
# 182075   Russia 2022-12-23     7357.0
# 182076   Russia 2022-12-24     6922.0
# 182077   Russia 2022-12-25     6550.0
#
# [1060 rows x 3 columns]

# %%
data_ncb.dropna()
data_ncb.info()
data_ncusa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116 entries, 30777 to 30892
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   location   116 non-null    object
#  1   date       116 non-null    datetime64[ns]
#  2   new_cases  112 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 3.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1069 entries, 230546 to 231614
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   location   1069 non-null   object
#  1   date       1069 non-null   datetime64[ns]
#  2   new_cases  1068 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 33.4+ KB

# %%
figure, axis = plt.subplots(nrows = 2, ncols = 2, figsize=(15, 15))

#Grafico Brasil
axis[0,0].plot(data_ncb['date'], data_ncb['new_cases'],color='blue')
axis[0,0].set_title("Brasil",fontsize=15)
axis[0,0].set_xlabel('Data', fontsize=15)

#Grafico Estados Unidos
axis[0,1].plot(data_ncusa['date'], data_ncusa['new_cases'],color='blue')
axis[0,1].set_title("Estados Unidos",fontsize=15)
axis[0,1].set_xlabel('Data', fontsize=15)

#Grafico China
axis[1,0].plot(data_ncchn['date'], data_ncchn['new_cases'],color='blue')
axis[1,0].set_title("China",fontsize=15)
axis[1,0].set_xlabel('Data', fontsize=15)

#Grafico Russia
axis[1,1].plot(data_ncrus['date'], data_ncrus['new_cases'],color='blue')
axis[1,1].set_title("Russia",fontsize=15)
axis[1,1].set_xlabel('Data', fontsize=15)
# Out:
# Text(0.5, 0, 'Data')

# %%
data_ncb = data_ncb.loc[(data_ncb['date']>='2022-09-01')]
# permite criar séries temporais a partir do tempo
timeSeries = data_ncb.loc[:, ["date","new_cases"]]
timeSeries.index = timeSeries.date
ts = timeSeries.drop("date",axis=1)

# %%
#Estacionariedade de uma série temporal

#Existem três critérios básicos para uma série temporal compreender se é uma série estacionária ou não.
    #As propriedades estatísticas das séries temporais, como média e variância, devem permanecer constantes ao longo do tempo para chamar séries temporais como estacionárias.
    #média constante
    #variação constante
    #autocovariância que não depende do tempo. autocovariância é covariância entre séries temporais e séries temporais defasadas.
#Permite visualizar e verificar a tendência de sazonalidade de nossas séries temporais.

rollingavg = ts.rolling(7).mean()
rollingstd = ts.rolling(7).std()

# %%
ts.dropna(inplace=True)
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 112 entries, 2022-09-01 to 2022-12-22
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   new_cases  112 non-null    float64
# dtypes: float64(1)
# memory usage: 1.8 KB

# %%
ts.head(10)
# Out:
#             new_cases
# date
# 2022-09-01        0.0
# 2022-09-02    26292.0
# 2022-09-03        0.0
# 2022-09-04        0.0
# 2022-09-05    21394.0
# 2022-09-06        0.0
# 2022-09-07        0.0
# 2022-09-08        0.0
# 2022-09-09    39200.0
# 2022-09-10        0.0

# %%
plt.figure( figsize = ( 12, 5)) 
plt.plot(ts,color='blue')
plt.plot(rollingavg,color='red')
plt.plot(rollingstd,color='green')
plt.title("Brasil",fontsize=15)
plt.xlabel('Data', fontsize=15)
# Out:
# Text(0.5, 0, 'Data')

# %%
#Agora vamos verificar estacionário de séries temporais. Podemos verificar a estacionariedade usando os seguintes métodos:
        #Plotting Rolling Statistics:: Temos uma janela, digamos que o tamanho da janela é 6 e, em seguida, encontramos a média e a variação do rolamento para verificar estacionário.
        #Teste Dickey-Fuller: Os resultados do teste incluem uma estatística de teste e alguns valores críticos para os níveis de confiança das diferenças. Se a estatística do teste for 
        #menor que o valor crítico, podemos dizer que as séries temporais são estacionárias.

# biblioteca adfuller
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(ts, autolag='AIC')
print('Test statistic: ' , result[0])
print('p-value: '  ,result[1])
print('Critical Values:' ,result[4])
# Out:
# Test statistic:  0.36810681676402085
# p-value:  0.98026226475368
# Critical Values: {'1%': -3.4961490537199116, '5%': -2.8903209639580556, '10%': -2.5821223452518263}

# %%
rollingdiff = ts - rollingavg
rollingdiff.dropna(inplace=True) # 6 primeiros é o valor nan devido ao tamanho da janela
rollingdiff.head()
# Out:
#                new_cases
# date
# 2022-09-07  -6812.285714
# 2022-09-08  -6812.285714
# 2022-09-09  30543.714286
# 2022-09-10  -8656.285714
# 2022-09-11  -8656.285714

# %%
rollingdiffavg = rollingdiff.rolling(7).mean()
rollingdiffstd = rollingdiff.rolling(7).std()

# %%
plt.figure( figsize = ( 12, 5)) 
plt.plot(ts,color='blue')
plt.plot(rollingdiffavg, color='red')
plt.plot(rollingdiffstd, color='green')
plt.title("Brasil",fontsize=15)
plt.xlabel('Data', fontsize=15)
# Out:
# Text(0.5, 0, 'Data')

# %%
result = adfuller(rollingdiff, autolag='AIC')
print('Test statistic: ' , result[0])
print('p-value: '  ,result[1])
print('Critical Values:' ,result[4])
# Out:
# Test statistic:  -3.662961334720566
# p-value:  0.004665349224899739
# Critical Values: {'1%': -3.505190196159122, '5%': -2.894232085048011, '10%': -2.5842101234567902}

# %%
# Biblioteca plot series diferenciais
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Biblioteca ARIMA
from statsmodels.tsa.arima.model import ARIMA
# prever todo o caminho
from sklearn.metrics import mean_squared_error
ts.head()
# Out:
#             new_cases
# date
# 2022-09-01        0.0
# 2022-09-02    26292.0
# 2022-09-03        0.0
# 2022-09-04        0.0
# 2022-09-05    21394.0

# %%
#Because, you need differencing only if the series is non-stationary. Else, no differencing is needed, that is, d=0.
#The null hypothesis of the ADF test is that the time series is non-stationary. So, if the p-value of the test is less than the significance level (0.05) then you reject the null hypothesis and infer that the time series is indeed stationary.
#So, in our case, if P Value > 0.05 we go ahead with finding the order of differencing.

result = adfuller(ts)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: 0.368107
# p-value: 0.980262

# %%
# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(ts.new_cases) 
axes[0, 0].set_title('Original Series')
result = plot_acf(ts.new_cases, lags=np.arange(len(ts)))

# 1st Differencing
axes[1, 0].plot(ts.new_cases.diff())
axes[1, 0].set_title('1st Order Differencing')
result = plot_acf(ts.new_cases.diff().dropna(),lags=np.arange(len(ts.new_cases.diff().dropna())))

# 2nd Differencing
axes[2, 0].plot(ts.new_cases.diff().diff())
axes[2, 0].set_title('2nd Order Differencing')
result = plot_acf(ts.new_cases.diff().diff().dropna(),lags=np.arange(len(ts.new_cases.diff().diff().dropna())))

# %%
# fit model
#ts.index = pd.to_timestamp(data=ts)
model2 = ARIMA(ts,order=(1,1,0)) # (ARMA) = (1,0,1)
model_fit2 = model2.fit()
print(model_fit2.summary())
predicts = model_fit2.fittedvalues
plt.plot(predicts, color='red')
#model_fit2.plot_predict(dynamic=false)
#forecast2 = model_fit2.predict()
error = mean_squared_error(ts, forecast2)
print("error: " ,error)
# visualização
#plt.figure(figsize=(22,10))
#plt.plot(ts,label = "original")
#plt.plot(forecast2,label = "predicted")
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              new_cases   No. Observations:                  112
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -1294.364
# Date:                Sat, 31 Dec 2022   AIC                           2592.727
# Time:                        00:04:16   BIC                           2598.146
# Sample:                    09-30-2022   HQIC                          2594.926
#                          - 12-31-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4694      0.054     -8.653      0.000      -0.576      -0.363
# sigma2      7.881e+08   2.76e-12   2.85e+20      0.000    7.88e+08    7.88e+08
# ...
# Ljung-Box (L1) (Q):                   4.17   Jarque-Bera (JB):               246.45
# ...

# %%
#to be continued
